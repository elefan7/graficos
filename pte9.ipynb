# %%
import pandas as pd
import numpy as np
from sklearn.manifold import TSNE
import plotly.graph_objects as go
import plotly.express as px

# %%
df = pd.read_csv('datos_procesados.csv')

# %%
df['Color']
# Out:
# 0        Vivo
# 1        Vivo
# 2        Vivo
# 3        Vivo
# 4        Vivo
#         ...
# 294    Muerto
# 295    Muerto
# 296    Muerto
# 297    Muerto
# 298    Muerto
# Name: Color, Length: 299, dtype: object

# %%
atributos_df = df.drop(columns=['DEATH_EVENT', 'Categoría de Edad'])

# %%
npy_matriz = atributos_df.values

# %%
npy_matriz
# Out:
# array([[7.500e+01, 0.000e+00, 5.820e+02, ..., 1.000e+00, 0.000e+00,
#         4.000e+00],
#        [5.500e+01, 0.000e+00, 7.861e+03, ..., 1.000e+00, 0.000e+00,
#         6.000e+00],
#        [6.500e+01, 0.000e+00, 1.460e+02, ..., 1.000e+00, 1.000e+00,
#         7.000e+00],
#        ...,
#        [4.500e+01, 0.000e+00, 2.060e+03, ..., 0.000e+00, 0.000e+00,
#         2.780e+02],
#        [4.500e+01, 0.000e+00, 2.413e+03, ..., 1.000e+00, 1.000e+00,
#         2.800e+02],
#        [5.000e+01, 0.000e+00, 1.960e+02, ..., 1.000e+00, 1.000e+00,
#         2.850e+02]])

# %%
objetivo = df['DEATH_EVENT']
arr_objetivo = objetivo.values

# %%
y = arr_objetivo

# %%
X_embedded = TSNE(
    n_components=3,
    learning_rate='auto',
    init='random',
    perplexity=3
).fit_transform(y.reshape(-1, 1))

dat = {'Dim_1': X_embedded[:, 0], 'Dim_2': X_embedded[:, 1], 'Dim_3': X_embedded[:, 2], 'DEATH_EVENT': y}
dt = pd.DataFrame(dat)
col_map = {0: 'Muerto', 1: 'Vivo'}
dt['Color'] = dt['DEATH_EVENT'].map(col_map)

fig = px.scatter_3d(dt, x='Dim_1', y='Dim_2', z='Dim_3', color='Color',
                    title='Grafico Dispersion 3D con Color por Clase')

fig.update_traces(marker=dict(size=4, opacity=0.8))
fig.show()
